# %%
from torchtext.data import get_tokenizer
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import spacy

from torchtext.vocab import build_vocab_from_iterator
# %matplotlib inline

# %%
tokenizer = get_tokenizer("basic_english")

# Open the file and read the contents
with open('data/war_and_peace.txt', 'r') as file:
    content = file.read() 
    
tokens = tokenizer(content)

# %%
# eng = spacy.load("en_core_web_sm")
# 
# FILE_PATH = 'data/war_and_peace.txt'

# %%
# build the vocabulary of characters and mappings to/from integers
words = sorted(list(set(tokens)))
stoi = {s:i for i,s in enumerate(words)}
itos = {i:s for s,i in stoi.items()}

# %%
stoi
# Out:
# {'!': 0,
#  '(': 1,
#  ')': 2,
#  '*': 3,
#  '*catherine': 4,
#  '*do': 5,
#  '*kutúzov': 6,
#  '*poisonous': 7,
#  '*—as': 8,
#  ',': 9,
#  '-': 10,
#  '.': 11,
#  '000': 12,
#  '07': 13,
#  '1': 14,
#  '10': 15,
#  '100': 16,
#  '102': 17,
#  '10—annette': 18,
#  '11': 19,
#  '110': 20,
#  '12': 21,
#  '120': 22,
#  '13': 23,
#  '130': 24,
#  '13th': 25,
#  '140': 26,
#  '15': 27,
#  '15/4': 28,
#  '150': 29,
#  '15y': 30,
#  '160': 31,
#  '17': 32,
#  '178': 33,
#  '1789': 34,
#  '1797': 35,
#  '17th': 36,
#  '18': 37,
#  '1805': 38,
#  '1805-6': 39,
#  '1806': 40,
#  '1807': 41,
#  '1808': 42,
#  '1809': 43,
#  '1809—precede': 44,
#  '1810': 45,
#  '1811': 46,
#  '1812': 47,
#  '1812—the': 48,
#  '1812—though': 49,
#  '1813': 50,
#  '1813—salute': 51,
#  '1815': 52,
#  '1820': 53,
#  '18th': 54,
#  '1st': 55,
#  '2': 56,
#  '20': 57,
#  '217': 58,
#  '22': 59,
#  '22nd': 60,
#  '23': 61,
#  '23rd': 62,
#  '24': 63,
#  '24th': 64,
#  '25': 65,
#  '25th': 66,
#  '26': 67,
#  '27': 68,
#  '27th': 69,
#  '3': 70,
#  '30': 71,
#  '31': 72,
#  '3rd': 73,
#  '4': 74,
#  '40': 75,
#  '4th': 76,
#  '4x': 77,
#  '5': 78,
#  '50': 79,
#  '6': 80,
#  '6-me': 81,
#  '60': 82,
#  '62': 83,
#  '666': 84,
#  '671': 85,
#  '6th': 86,
#  '6—st': 87,
#  '7': 88,
#  '70': 89,
#  '700': 90,
#  '7th': 91,
#  '8': 92,
#  '80': 93,
#  '86th': 94,
#  '8th': 95,
#  '9': 96,
#  '90': 97,
#  '9th': 98,
#  '=': 99,
#  '?': 100,
#  'a': 101,
#  'ab': 102,
#  'aback': 103,
#  'abacus': 104,
#  'abandon': 105,
#  'abandoned': 106,
#  'abandoning': 107,
#  'abandonment': 108,
#  'abandons': 109,
#  'abashed': 110,
#  'abate': 111,
#  'abbreviations': 112,
#  'abbé': 113,
#  'abbé’s': 114,
#  'abc': 115,
#  'abdicate': 116,
#  'abdomen': 117,
#  'abdomens': 118,
#  'abduction': 119,
#  'abductors': 120,
#  'abhorrence': 121,
#  'ability': 122,
#  'ablaze': 123,
#  'able': 124,
#  'abnormal': 125,
#  'abnormally': 126,
#  'abodes': 127,
#  'abolition': 128,
#  'abominable': 129,
#  'abominably': 130,
#  'abounding': 131,
#  'about': 132,
#  'about—i': 133,
#  'about—”': 134,
#  'above': 135,
#  'aboveboard': 136,
#  'abreast': 137,
#  'abroad': 138,
#  'abrupt': 139,
#  'abruptly': 140,
#  'abrámovna': 141,
#  'absence': 142,
#  'absent': 143,
#  'absent-minded': 144,
#  'absent-mindedly': 145,
#  'absent-mindedness': 146,
#  'absentees': 147,
#  'absently': 148,
#  'absolute': 149,
#  'absolutely': 150,
#  'absolved': 151,
#  'absorb': 152,
#  'absorbed': 153,
#  'absorption': 154,
#  'abstain': 155,
#  'abstained': 156,
#  'abstaining': 157,
#  'abstemious': 158,
#  'abstention': 159,
#  'abstract': 160,
#  'abstraction': 161,
#  'absurd': 162,
#  'absurdity': 163,
#  'absurdly': 164,
#  'abundance': 165,
#  'abundant': 166,
#  'abundantly': 167,
#  'abuse': 168,
#  'abused': 169,
#  'abuses': 170,
#  'abusing': 171,
#  'abyss': 172,
#  'academy': 173,
#  'accelerate': 174,
#  'accent': 175,
#  'accents': 176,
#  'accentuated': 177,
#  'accentuating': 178,
#  'accent—having': 179,
#  'accept': 180,
#  'acceptance': 181,
#  'accepted': 182,
#  'accepting': 183,
#  'accepts': 184,
#  'access': 185,
#  'accessible': 186,
#  'accident': 187,
#  'accidental': 188,
#  'accidentally': 189,
#  'accidently': 190,
#  'accidents': 191,
#  'acclaimed': 192,
#  'acclamations': 193,
#  'accommodate': 194,
#  'accommodated': 195,
#  'accommodation': 196,
#  'accompanied': 197,
#  'accompanies': 198,
#  'accompaniment': 199,
#  'accompany': 200,
#  'accompanying': 201,
#  'accomplish': 202,
#  'accomplished': 203,
#  'accomplished—were': 204,
#  'accomplishing': 205,
#  'accomplishment': 206,
#  'accomplishments': 207,
#  'accord': 208,
#  'accordance': 209,
#  'accorded': 210,
#  'according': 211,
#  'accordingly': 212,
#  'accoucheur': 213,
#  'account': 214,
#  'accountant': 215,
#  'accounted': 216,
#  'accounts': 217,
#  'accouterments': 218,
#  'accrue': 219,
#  'accumulated': 220,
#  'accuracy': 221,
#  'accurate': 222,
#  'accurately': 223,
#  'accusations': 224,
#  'accuse': 225,
#  'accused': 226,
#  'accusers': 227,
#  'accuses': 228,
#  'accusing': 229,
#  'accustom': 230,
#  'accustomed': 231,
#  'ace': 232,
#  'ache': 233,
#  'aches': 234,
#  'ache—it': 235,
#  'achieve': 236,
#  'achieved': 237,
#  'achievement': 238,
#  'achievements': 239,
#  'achievement—though': 240,
#  'achilles': 241,
#  'achilles’': 242,
#  'aching': 243,
#  'achtung': 244,
#  'acid': 245,
#  'acknowledge': 246,
#  'acknowledged': 247,
#  'acknowledging': 248,
#  'acknowledgment': 249,
#  'acme': 250,
#  'acquaintance': 251,
#  'acquaintances': 252,
#  'acquaintance—he': 253,
#  'acquainted': 254,
#  'acquire': 255,
#  'acquired': 256,
#  'acquiring': 257,
#  'acquitted': 258,
#  'acre': 259,
#  'acres': 260,
#  'acrid': 261,
#  'across': 262,
#  'act': 263,
#  'acted': 264,
#  'acting': 265,
#  'action': 266,
#  'actions': 267,
#  'actions—without': 268,
#  'action—he': 269,
#  'action—seeing': 270,
#  'action—the': 271,
#  'active': 272,
#  'actively': 273,
#  'activities': 274,
#  'activities—the': 275,
#  'activity': 276,
#  'activity—in': 277,
#  'activity—the': 278,
#  'actor': 279,
#  'actors': 280,
#  'actor’s': 281,
#  'actress': 282,
#  'actresses': 283,
#  'actresses—with': 284,
#  'actress’': 285,
#  'acts': 286,
#  'actual': 287,
#  'actually': 288,
#  'actuated': 289,
#  'act—act': 290,
#  'acute': 291,
#  'acutely': 292,
#  'adam': 293,
#  'adapt': 294,
#  'adaptations': 295,
#  'adapted': 296,
#  'adapting': 297,
#  'add': 298,
#  'added': 299,
#  'added—allusions': 300,
#  'added—that': 301,
#  'addicted': 302,
#  'adding': 303,
#  'addition': 304,
#  'additional': 305,
#  'additions': 306,
#  'address': 307,
#  'addressed': 308,
#  'addressing': 309,
#  'adducing': 310,
#  'adept': 311,
#  'adequately': 312,
#  'adhere': 313,
#  'adhered': 314,
#  'adherents': 315,
#  'adherents—military': 316,
#  'adhesion': 317,
#  'adieu': 318,
#  'adjacent': 319,
#  'adjoining': 320,
#  'adjust': 321,
#  'adjusted': 322,
#  'adjusting': 323,
#  'adjutant': 324,
#  'adjutant-general': 325,
#  'adjutants': 326,
#  'adjutants-general': 327,
#  'adjutants—was': 328,
#  'adjutant—a': 329,
#  'adjutant’s': 330,
#  'administer': 331,
#  'administered': 332,
#  'administration': 333,
#  'administrative': 334,
#  'administrator': 335,
#  'administrators': 336,
#  'admirable': 337,
#  'admirably': 338,
#  'admiral': 339,
#  'admiration': 340,
#  'admire': 341,
#  'admired': 342,
#  'admirer': 343,
#  'admires': 344,
#  'admiring': 345,
#  'admiringly': 346,
#  'admission': 347,
#  'admit': 348,
#  'admits': 349,
#  'admitted': 350,
#  'admitting': 351,
#  'admit—he': 352,
#  'admonish': 353,
#  'admonishing': 354,
#  'admonishingly': 355,
#  'admonitory': 356,
#  'adonai': 357,
#  'adopt': 358,
#  'adopted': 359,
#  'adopting': 360,
#  'adorable': 361,
#  'adoration': 362,
#  'adore': 363,
#  'adored': 364,
#  'adorer': 365,
#  'adorers': 366,
#  'adores': 367,
#  'adoring': 368,
#  'adorn': 369,
#  'adorning': 370,
#  'adornment': 371,
#  'adroit': 372,
#  'adroitly': 373,
#  'adroitness': 374,
#  'adráksin': 375,
#  'adulation': 376,
#  'advance': 377,
#  'advanced': 378,
#  'advances': 379,
#  'advancing': 380,
#  'advantage': 381,
#  'advantageous': 382,
#  'advantageously': 383,
#  'advantages': 384,
#  'advent': 385,
#  'adventure': 386,
#  'adventures': 387,
#  'adversary': 388,
#  'adversary’s': 389,
#  'adve’sawies': 390,
#  'advice': 391,
#  'advice—or': 392,
#  'advisable': 393,
#  'advise': 394,
#  'advised': 395,
#  'adviser': 396,
#  'advisers': 397,
#  'advising': 398,
#  'advocated': 399,
#  'advocates': 400,
#  'advocating': 401,
#  'aerial': 402,
#  'afar': 403,
#  'affability': 404,
#  'affable': 405,
#  'affably': 406,
#  'affair': 407,
#  'affairs': 408,
#  'affairs—near': 409,
#  'affairs—this': 410,
#  'affairs—which': 411,
#  'affair—this': 412,
#  'affair—yes': 413,
#  'affect': 414,
#  'affectation': 415,
#  'affected': 416,
#  'affecting': 417,
#  'affection': 418,
#  'affectionate': 419,
#  'affectionately': 420,
#  'affetto': 421,
#  'affianced': 422,
#  'affinity': 423,
#  'affirm': 424,
#  'affirmative': 425,
#  'affirmatively': 426,
#  'affirming': 427,
#  'afflicted': 428,
#  'afford': 429,
#  'afforded': 430,
#  'affording': 431,
#  'affords': 432,
#  'affright': 433,
#  'affronted': 434,
#  'affronts': 435,
#  'aflame': 436,
#  'afloat': 437,
#  'afraid': 438,
#  'afraid—afraid': 439,
#  'afraid—but': 440,
#  'afresh': 441,
#  'africa': 442,
#  'africans': 443,
#  'after': 444,
#  'after-dinner': 445,
#  'afterglow': 446,
#  'afterlife': 447,
#  'afternoon': 448,
#  'afterward': 449,
#  'afterwards': 450,
#  'afwaid': 451,
#  'again': 452,
#  'against': 453,
#  'again—another': 454,
#  'again—as': 455,
#  'again—though': 456,
#  'agate': 457,
#  'age': 458,
#  'aged': 459,
#  'agencies': 460,
#  'agent': 461,
#  'agents': 462,
#  'ages': 463,
#  'age—i': 464,
#  'aggrandizement': 465,
#  'aggression': 466,
#  'aggressive': 467,
#  'aggressor': 468,
#  'aggrieved': 469,
#  'aghast': 470,
#  'agile': 471,
#  'agile—she': 472,
#  'agility': 473,
#  'agitated': 474,
#  'agitating': 475,
#  'agitation': 476,
#  'aglow': 477,
#  'ago': 478,
#  'agonized': 479,
#  'agonizing': 480,
#  'agonizingly': 481,
#  'agony': 482,
#  'agraféna': 483,
#  'agree': 484,
#  'agreeable': 485,
#  'agreeable—she': 486,
#  'agreeably': 487,
#  'agreed': 488,
#  'agreeing': 489,
#  'agreement': 490,
#  'agricultural': 491,
#  'agriculture': 492,
#  'agriculturists': 493,
#  'ague': 494,
#  'agwee': 495,
#  'ah': 496,
#  'ah-ing': 497,
#  'ahead': 498,
#  'aid': 499,
#  'aide-de-camp': 500,
#  'aide-de-camp’s': 501,
#  'aided': 502,
#  'aides-de-camp': 503,
#  'ailing': 504,
#  'aim': 505,
#  'aime': 506,
#  'aimed': 507,
#  'aime’': 508,
#  'aiming': 509,
#  'aimless': 510,
#  'aimlessly': 511,
#  'aims': 512,
#  'aims—only': 513,
#  'aims—the': 514,
#  'aim—to': 515,
#  'air': 516,
#  'airiness': 517,
#  'airs': 518,
#  'airy': 519,
#  'akhrosímova': 520,
#  'akhárovs’': 521,
#  'akimbo': 522,
#  'akin': 523,
#  'akínfi': 524,
#  'alarm': 525,
#  'alarmed': 526,
#  'alarming': 527,
#  'alarms': 528,
#  'album': 529,
#  'albums': 530,
#  'alcohol': 531,
#  'alders': 532,
#  'alert': 533,
#  'alertly': 534,
#  'alertness': 535,
#  'alexander': 536,
#  'alexanders': 537,
#  'alexanders—bekleshëv': 538,
#  'alexander—generals': 539,
#  'alexander—just': 540,
#  'alexander—though': 541,
#  'alexander’s': 542,
#  'alexandre': 543,
#  'alexéevich': 544,
#  'alexéevich’s': 545,
#  'alexéevna': 546,
#  'alexéy': 547,
#  'algebra': 548,
#  'alien': 549,
#  'alienated': 550,
#  'alienating': 551,
#  'alight': 552,
#  'alighted': 553,
#  'alighting': 554,
#  'aligning': 555,
#  'alike': 556,
#  'alike—turned': 557,
#  'alike—were': 558,
#  'aliment': 559,
#  'alimony': 560,
#  'aline': 561,
#  'alive': 562,
#  'alive—a': 563,
#  'alive—he': 564,
#  'alive—live': 565,
#  'all': 566,
#  'all-embracing': 567,
#  'all-forgiving': 568,
#  'all-good': 569,
#  'all-important': 570,
#  'all-powerful': 571,
#  'all-seeing': 572,
#  'all-transforming': 573,
#  'allait-il': 574,
#  'allay': 575,
#  'alleged': 576,
#  'allegiance': 577,
#  'allegories': 578,
#  'allegory': 579,
#  'alley': 580,
#  'alleys': 581,
#  'allez-vous': 582,
#  'alliance': 583,
#  'alliances': 584,
#  'allied': 585,
#  'allies': 586,
#  'allies—the': 587,
#  'alliée': 588,
#  'alliés': 589,
#  'allons': 590,
#  'allopaths': 591,
#  'allot': 592,
#  'allotted': 593,
#  'allow': 594,
#  'allowance': 595,
#  'allowed': 596,
#  'allowing': 597,
#  'allows': 598,
#  'allude': 599,
#  'alluded': 600,
#  'alluding': 601,
#  'allured': 602,
#  'allurement': 603,
#  'allurements': 604,
#  'alluringly': 605,
#  'allusion': 606,
#  'allusions': 607,
#  'ally': 608,
#  'all—carried': 609,
#  'all—everything': 610,
#  'all—for': 611,
#  'all—read': 612,
#  'all—she': 613,
#  'all—with': 614,
#  'all’s': 615,
#  'almighty': 616,
#  'almond-shaped': 617,
#  'almonds': 618,
#  'almost': 619,
#  'alms': 620,
#  'almshouse': 621,
#  'almshouses': 622,
#  'alms”': 623,
#  'aloft': 624,
#  'alone': 625,
#  'alone—for': 626,
#  'alone—incurring': 627,
#  'alone—the': 628,
#  'alone—who': 629,
#  'alone—with': 630,
#  'along': 631,
#  'alongside': 632,
#  'aloof': 633,
#  'aloofness': 634,
#  'aloud': 635,
#  'alphabet': 636,
#  'alphonse': 637,
#  'alpátych': 638,
#  'alpátych’s': 639,
#  'already': 640,
#  'already’': 641,
#  'alsatian': 642,
#  'also': 643,
#  'altar': 644,
#  'altars': 645,
#  'alte': 646,
#  'alter': 647,
#  'alterations': 648,
#  'altercation': 649,
#  'altered': 650,
#  'altering': 651,
#  'alternate': 652,
#  'alternated': 653,
#  'alternately': 654,
#  'alternating': 655,
#  'alternative': 656,
#  'although': 657,
#  'altogether': 658,
#  'always': 659,
#  'alénina': 660,
#  'aléxis': 661,
#  'alësha': 662,
#  'am': 663,
#  'amalek': 664,
#  'amant': 665,
#  'amants': 666,
#  'amazed': 667,
#  'amazement': 668,
#  'amazing': 669,
#  'amazingly': 670,
#  'amazon': 671,
#  'ambassador': 672,
#  'ambassadors': 673,
#  'ambassador’s': 674,
#  'amber': 675,
#  'ambition': 676,
#  'ambitious': 677,
#  'amble': 678,
#  'ambled': 679,
#  'ambler': 680,
#  'ambling': 681,
#  'ambulance': 682,
#  'ambuscade': 683,
#  'ambush': 684,
#  'amelie': 685,
#  'amen': 686,
#  'amenities': 687,
#  'america': 688,
#  'ami': 689,
#  'amiabilities': 690,
#  'amiability': 691,
#  'amiable': 692,
#  'amiably': 693,
#  'amicable': 694,
#  'amid': 695,
#  'amidst': 696,
#  'amie': 697,
#  'amiss': 698,
#  'ammunition': 699,
#  'among': 700,
#  'amongst': 701,
#  'amorous': 702,
#  'amount': 703,
#  'amounted': 704,
#  'amoureuse': 705,
#  'amphilochus': 706,
#  'amphitheater': 707,
#  'ample': 708,
#  'amputated': 709,
#  'amstetten': 710,
#  'amulet': 711,
#  'amuse': 712,
#  'amused': 713,
#  'amusement': 714,
#  'amusements': 715,
#  'amusement—almost': 716,
#  'amuses': 717,
#  'amusing': 718,
#  'amusingly': 719,
#  'amélie’s': 720,
#  'amélie”': 721,
#  'an': 722,
#  'analogy': 723,
#  'analysis': 724,
#  'analyze': 725,
#  'analyzing': 726,
#  'anarchy': 727,
#  'anathematized': 728,
#  'anatole': 729,
#  'anatole’s': 730,
#  'ancestor': 731,
#  'ancestors': 732,
#  'ancestral': 733,
#  'ancient': 734,
#  'ancients': 735,
#  'and': 736,
#  'and-so': 737,
#  'andrew': 738,
#  'andrew—a': 739,
#  'andrew—and': 740,
#  'andrew—promised': 741,
#  'andrew—relapsing': 742,
#  'andrew—she': 743,
#  'andrew—spoke': 744,
#  'andrew—“not': 745,
#  'andrew’s': 746,
#  'andrew”': 747,
#  'andré': 748,
#  'andréevich': 749,
#  'andréevich—': 750,
#  'andréevich”': 751,
#  'andrúsha': 752,
#  'andrúsha—the': 753,
#  'andrúsha’s': 754,
#  'andwew': 755,
#  'and—as': 756,
#  'and—like': 757,
#  'and—now': 758,
#  'and—what': 759,
#  'and—with': 760,
#  'and—“puff”': 761,
#  'anecdote': 762,
#  'anecdotes': 763,
#  'anew': 764,
#  'anew—but': 765,
#  'anférovs': 766,
#  'angel': 767,
#  'angelic': 768,
#  'angelically': 769,
#  'angels': 770,
#  'angel—as': 771,
#  'angel’s': 772,
#  'anger': 773,
#  'angered': 774,
#  'angina': 775,
#  'anglaise': 776,
#  'angle': 777,
#  'angles': 778,
#  'angle—so': 779,
#  'angle—we': 780,
#  'angling': 781,
#  'angrier': 782,
#  'angrily': 783,
#  'angrily—“that': 784,
#  'angry': 785,
#  'angry—but': 786,
#  'angry—that': 787,
#  'anguish': 788,
#  'animal': 789,
#  'animals': 790,
#  'animals—from': 791,
#  'animal’s': 792,
#  'animate': 793,
#  'animated': 794,
#  'animatedly': 795,
#  'animating': 796,
#  'animation': 797,
#  'animosity': 798,
#  'ankle-deep': 799,
#  'ankles': 800,
#  'anna': 801,
#  'annals': 802,
#  'anne': 803,
#  'annette': 804,
#  'annette—how': 805,
#  'annette’s': 806,
#  'annex': 807,
#  'annihilate': 808,
#  'annihilated': 809,
#  'annihilating': 810,
#  'anniversary': 811,
#  'announce': 812,
#  'announced': 813,
#  'announcement': 814,
#  'announcements': 815,
#  'announces': 816,
#  'announcing': 817,
#  'annoyance': 818,
#  'annoyed': 819,
#  'annoying': 820,
#  'anointed': 821,
#  'anonymous': 822,
#  'another': 823,
#  'another—a': 824,
#  'another—and': 825,
#  'another—bernadotte': 826,
#  'another—pierre': 827,
#  'another—that': 828,
#  'another’s': 829,
#  'another’s—a': 830,
#  'ansicht': 831,
#  'answer': 832,
#  'answered': 833,
#  'answering': 834,
#  'answers': 835,
#  'answer—as': 836,
#  'ant-hill': 837,
#  'antagonism': 838,
#  'antagonistic': 839,
#  'antagonists': 840,
#  'antagonist’s': 841,
#  'antecedents': 842,
#  'antechamber': 843,
#  'antechambers': 844,
#  'anteroom': 845,
#  'anterooms': 846,
#  'anti-french': 847,
#  'antichrist': 848,
#  'antichrist—i': 849,
#  'anticipate': 850,
#  'anticipated': 851,
#  'anticipating': 852,
#  'anticipation': 853,
#  'antidotes': 854,
#  'antinational': 855,
#  'antipathetic': 856,
#  'antipathies': 857,
#  'antipathy': 858,
#  'antique': 859,
#  'antiquity': 860,
#  'ants': 861,
#  'antón': 862,
#  'antónov': 863,
#  'antónovna': 864,
#  'antónovna’s': 865,
#  'anxieties': 866,
#  'anxiety': 867,
#  'anxious': 868,
#  'anxiously': 869,
#  'any': 870,
#  'anybody': 871,
#  'anybody”—but': 872,
#  'anyhow': 873,
#  'anyone': 874,
#  'anyone—all': 875,
#  'anyone—to': 876,
#  'anyone—while': 877,
#  'anyone’s': 878,
#  'anything': 879,
#  'anything—we': 880,
#  'anyway': 881,
#  'anywhere': 882,
#  'any—were': 883,
#  'aníska': 884,
#  'anísya': 885,
#  'anísya’s': 886,
#  'apart': 887,
#  'apartment': 888,
#  'apartments': 889,
#  'apathetic': 890,
#  'apathy': 891,
#  'ape': 892,
#  'apes': 893,
#  'apex': 894,
#  'apocalypse': 895,
#  'apollón': 896,
#  'apologetically': 897,
#  'apologies': 898,
#  'apologize': 899,
#  'apologizing': 900,
#  'apology': 901,
#  'apoplectic': 902,
#  'appalled': 903,
#  'apparent': 904,
#  'apparently': 905,
#  'apparent—such': 906,
#  'apparition': 907,
#  'appeal': 908,
#  'appealed': 909,
#  'appealing': 910,
#  'appeals': 911,
#  'appeal—that': 912,
#  'appear': 913,
#  'appearance': 914,
#  'appearance—that': 915,
#  'appeared': 916,
#  'appeared—now': 917,
#  'appearing': 918,
#  'appears': 919,
#  'appease': 920,
#  'appeased': 921,
#  'appellation': 922,
#  'appellations': 923,
#  'appetizing': 924,
#  'applauding': 925,
#  'applause': 926,
#  'apple': 927,
#  'apples': 928,
#  'applicable': 929,
#  'application': 930,
#  'applications': 931,
#  'applied': 932,
#  'applies': 933,
#  'apply': 934,
#  'applying': 935,
#  'appoint': 936,
#  'appointed': 937,
#  'appointment': 938,
#  'appointments': 939,
#  'apportioned': 940,
#  'appositely': 941,
#  'appositeness': 942,
#  'appraised': 943,
#  'appraising': 944,
#  'appreciate': 945,
#  'appreciated': 946,
#  'appreciating': 947,
#  'appreciation': 948,
#  'appreciative': 949,
#  'apprehend': 950,
#  'apprehended': 951,
#  'apprehension': 952,
#  'apprehensive': 953,
#  'apprenticeship': 954,
#  'approach': 955,
#  'approached': 956,
#  'approaches': 957,
#  'approaching': 958,
#  'approbation': 959,
#  'appropriate': 960,
#  'appropriated': 961,
#  'appropriately': 962,
#  'approval': 963,
#  'approve': 964,
#  'approved': 965,
#  'approving': 966,
#  'approvingly': 967,
#  'approximate': 968,
#  'approximately': 969,
#  'approximation': 970,
#  'appwove': 971,
#  'april': 972,
#  'apron': 973,
#  'aprons': 974,
#  'apráksin': 975,
#  'apráksina': 976,
#  'apráksins’': 977,
#  'apt': 978,
#  'aptitude': 979,
#  'aquaintances': 980,
#  'ar': 981,
#  'arab': 982,
#  'arakchéev': 983,
#  'arakchéev’s': 984,
#  'arbiter': 985,
#  'arbiters': 986,
#  'arbitrarily': 987,
#  'arbitrariness': 988,
#  'arbitrary': 989,
#  'arbát': 990,
#  'arc': 991,
#  'arcade': 992,
#  'arch': 993,
#  'archduchess': 994,
#  'archduchess’': 995,
#  'archduchy': 996,
#  'archduke': 997,
#  'archduke’s': 998,
#  'arched': 999,
#  ...}

# %%
len(stoi)
# Out:
# 21731

# %%
# build the dataset

# context length: how many characters we take to predict the next one
block_size = 3

X, Y = [], []

context = [0] * block_size

for token in tokens:
    ix = stoi[token]
    X.append(context)
    Y.append(ix)
    # print(", ".join(itos[i] for i in context), "--->", itos[ix])
    context = context[1:] + [ix]

X = torch.tensor(X)
Y = torch.tensor(Y)

# %%
occurrences = {}

for token in tokens:
    if stoi[token] in occurrences:
        occurrences[stoi[token]] += 1
    else:
        occurrences[stoi[token]] = 1

# %%
sorted_occurrences = sorted(occurrences.items(), key=lambda item: item[1], reverse=True)
sorted_occurrences
# Out:
# [(9, 39744),
#  (17993, 34127),
#  (11, 30659),
#  (736, 21745),
#  (18297, 16552),
#  (12375, 14852),
#  (101, 10351),
#  (8322, 9668),
#  (9118, 8837),
#  (21712, 8611),
#  (8592, 7957),
#  (17982, 7697),
#  (19733, 7322),
#  (20108, 5633),
#  (8135, 5351),
#  (9707, 5031),
#  (8416, 4695),
#  (12156, 4598),
#  (8523, 4566),
#  (1226, 4497),
#  (12449, 3958),
#  (1128, 3945),
#  (0, 3925),
#  (2460, 3664),
#  (7097, 3465),
#  (16153, 3361),
#  (8884, 3295),
#  (20392, 3257),
#  (9690, 3232),
#  (100, 3135),
#  (15530, 2834),
#  (566, 2697),
#  (7379, 2664),
#  (1600, 2414),
#  (19886, 2405),
#  (2492, 2373),
#  (18064, 2086),
#  (19987, 2069),
#  (18124, 2010),
#  (12451, 2004),
#  (19939, 2001),
#  (19910, 1982),
#  (8306, 1943),
#  (13838, 1867),
#  (16665, 1789),
#  (13275, 1779),
#  (722, 1613),
#  (19181, 1550),
#  (18005, 1512),
#  (12525, 1503),
#  (1661, 1474),
#  (4871, 1469),
#  (19924, 1453),
#  (18003, 1437),
#  (18041, 1364),
#  (17001, 62),
#  (1914, 62),
#  (6409, 61),
#  (6433, 61),
#  (14576, 61),
#  (10984, 61),
#  (7858, 61),
#  (308, 61),
#  (18177, 61),
#  (16482, 61),
#  (21474, 61),
#  (2111, 61),
#  (10413, 61),
#  ...]

# %%
X.shape, Y.shape
# Out:
# (torch.Size([650138, 3]), torch.Size([650138]))

# %%
C = torch.randn(21732, 2)

# because we use a block size of 3, the shape of the input layer will be 2*3 (embedding size * context size)
W1 = torch.randn((6, 1000))
b1 = torch.randn(1000)
W2 = torch.randn((1000, 21732))
b2 = torch.randn(21732)

parameters = [C, W1, b1, W2, b2]

# %%
emb = C[X]
emb.shape
# Out:
# torch.Size([650138, 3, 2])

# %%
s = 0
for p in parameters:
    print(p.nelement())
    s += p.nelement()
    
print(f'sum of parameters: {s}')
# Out:
# 43464
# 6000
# 1000
# 21732000
# 21732
# sum of parameters: 21804196

# %%
for p in parameters:
    p.requires_grad = True

# %%
# exponentiated learning rate
ex_steps = 200
lre = torch.linspace(-3, 0, ex_steps)
lrs = 10**lre

# %%
lri = []
lossi = []

for i in range(ex_steps):

    # minibatch construct 
    ix = torch.randint(0, X.shape[0], (32, ))

    emb = C[X[ix]] 
    h = torch.tanh(emb.view(-1, 6) @ W1 + b1)
    logits = h @ W2 + b2
    loss = F.cross_entropy(logits, Y[ix])
    print(loss.item())
    # backward pass
    for p in parameters:
        p.grad = None    
    loss.backward()

    lr = lrs[i]
    for p in parameters:
        p.data += -lr * p.grad

    # track stats
    lri.append(lre[i])
    lossi.append(loss.item())
# Out:
# 60.54430389404297
# 61.85414505004883
# 56.409053802490234
# 53.55885314941406
# 53.315155029296875
# 70.68470764160156
# 63.40306091308594
# 54.75712966918945
# 55.603179931640625
# 59.41386795043945
# 54.39002227783203
# 57.762779235839844
# 60.83958053588867
# 61.55419921875
# 57.56349563598633
# 47.52362823486328
# 65.74260711669922
# 57.777645111083984
# 55.10300064086914
# 56.266056060791016
# 72.25538635253906
# 53.00238800048828
# 55.70478439331055
# 51.842796325683594
# 54.50331115722656
# 56.349979400634766
# 56.7021484375
# 59.530799865722656
# 60.03456497192383
# 61.12183380126953
# 51.32437515258789
# 56.85642623901367
# 55.13302230834961
# 63.48041534423828
# 59.895782470703125
# 59.91879653930664
# 59.15512466430664
# 55.3447380065918
# 57.74300765991211
# 53.44746017456055
# 58.446876525878906
# 46.784034729003906
# 66.85449981689453
# 60.47269821166992
# 48.548709869384766
# 63.32386016845703
# 49.81611633300781
# 59.07807159423828
# 61.93089294433594
# 66.34486389160156
# 53.76069259643555
# 57.85449981689453
# 61.06758117675781
# 57.62962341308594
# 53.85675048828125
# 49.63001251220703
# 59.91035461425781
# 58.04438400268555
# 59.91199493408203
# 64.25831604003906
# 55.446449279785156
# 54.95185852050781
# 54.74456787109375
# 63.554161071777344
# 56.430938720703125
# 63.047454833984375
# 55.05475616455078
# 61.26604461669922
# 56.28376007080078
# 50.998870849609375
# 45.21341323852539
# 50.734130859375
# 50.911643981933594
# 55.594993591308594
# 48.287147521972656
# 62.92877197265625
# 55.55556106567383
# 55.2567138671875
# 46.93457794189453
# 58.562381744384766
# 57.78731918334961
# 56.32078552246094
# 51.395626068115234
# 57.43917465209961
# 53.47404861450195
# 54.95526885986328
# 49.982139587402344
# 63.02074432373047
# 59.1591682434082
# 52.815399169921875
# 56.45343780517578
# 55.283546447753906
# 65.57677459716797
# 58.46440124511719
# 56.909969329833984
# 50.86550521850586
# 56.38677215576172
# 51.849891662597656
# 56.95981216430664
# 54.074012756347656
# 52.86489486694336
# 55.657325744628906
# 60.549625396728516
# 59.172298431396484
# 58.661739349365234
# 61.13713836669922
# 46.69905090332031
# 35.85559844970703
# 50.911155700683594
# 46.196556091308594
# 52.61742401123047
# 53.56520462036133
# 54.566776275634766
# 55.408668518066406
# 52.568748474121094
# 59.21079635620117
# 56.43424606323242
# 53.193538665771484
# 59.81034469604492
# 51.459781646728516
# 47.070316314697266
# 45.12849426269531
# 56.1112174987793
# 55.999908447265625
# 62.094242095947266
# 50.400455474853516
# 57.247581481933594
# 53.20779800415039
# 57.34817886352539
# 57.73457336425781
# 55.775455474853516
# 59.7225341796875
# 48.841861724853516
# 56.84273147583008
# 61.21913528442383
# 47.164649963378906
# 62.84952926635742
# 56.47994613647461
# 46.454341888427734
# 54.92563247680664
# 39.298126220703125
# 53.29116439819336
# 51.77552795410156
# 50.33758544921875
# 58.77058410644531
# 59.804481506347656
# 62.58552932739258
# 58.736202239990234
# 51.67069625854492
# 41.8506965637207
# 60.624935150146484
# 60.63042449951172
# 48.679359436035156
# 54.16334533691406
# 42.18608093261719
# 61.63867950439453
# 57.828590393066406
# 57.525779724121094
# 49.27101135253906
# 67.5376205444336
# 57.24972152709961
# 56.340240478515625
# 63.31291198730469
# 52.93403625488281
# 64.76957702636719
# 60.59724044799805
# 52.910152435302734
# 54.8995475769043
# 54.2190055847168
# 57.862510681152344
# 64.31989288330078
# 60.87675857543945
# 58.89706802368164
# 62.5135498046875
# 57.61587142944336
# 59.08565139770508
# 64.22090911865234
# 59.154823303222656
# 67.84467315673828
# 56.73151397705078
# 70.67697143554688
# 65.79682159423828
# 55.80415725708008
# 77.3350830078125
# 76.13621520996094
# 69.83649444580078
# 71.74077606201172
# 61.10940933227539
# 59.34015655517578
# 62.5057373046875
# 64.88003540039062
# 67.81452941894531
# 68.91975402832031
# 76.81370544433594
# 76.25326538085938
# 74.1812744140625
# 78.3949203491211
# 85.66451263427734
# 76.36193084716797
# 80.42687225341797

# %%
plt.plot(lri, lossi)
plt.xlabel('Exponentiated Learning Rate')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
10 ** -1
# Out:
# 0.1

# %%
lossi = []
stepi = []

for i in range(100):

    # minibatch construct 
    ix = torch.randint(0, X.shape[0], (32, ))

    emb = C[X[ix]] 
    h = torch.tanh(emb.view(-1, 6) @ W1 + b1)
    logits = h @ W2 + b2
    loss = F.cross_entropy(logits, Y[ix])
    print(loss.item())
    # backward pass
    for p in parameters:
        p.grad = None    
    loss.backward()
    
    lr = 0.1
    
    for p in parameters:
        p.data += -lr * p.grad
        
    # track stats
    stepi.append(i)
    lossi.append(loss.log10().item())
# Out:
# 79.27024841308594
# 76.7458267211914
# 80.02503204345703
# 79.44893646240234
# 74.14470672607422
# 72.28154754638672
# 78.53472900390625
# 68.3566665649414
# 81.77951049804688
# 69.77386474609375
# 60.37277603149414
# 68.06349182128906
# 64.63290405273438
# 58.76641082763672
# 65.68611145019531
# 51.54001998901367
# 66.86566925048828
# 57.1289176940918
# 54.99138259887695
# 55.43575668334961
# 58.35314178466797
# 53.49834442138672
# 47.69317626953125
# 55.56327819824219
# 61.60887145996094
# 62.631107330322266
# 72.17310333251953
# 63.06821823120117
# 45.27052688598633
# 61.39672088623047
# 58.13935089111328
# 51.364341735839844
# 60.99612045288086
# 49.24863052368164
# 49.83234786987305
# 47.840721130371094
# 46.85386657714844
# 47.98756790161133
# 57.0139274597168
# 61.73564529418945
# 49.28899002075195
# 50.611663818359375
# 44.78900909423828
# 50.057613372802734
# 54.19983673095703
# 41.780921936035156
# 57.120872497558594
# 46.96268081665039
# 53.94892883300781
# 52.90521240234375
# 51.597442626953125
# 54.613136291503906
# 38.11160659790039
# 41.678977966308594
# 45.04110336303711
# 36.95228576660156
# 48.08430099487305
# 53.34614562988281
# 42.78041076660156
# 43.577457427978516
# 46.759033203125
# 44.24495315551758
# 44.49867248535156
# 51.55078887939453
# 53.98603820800781
# 46.92097854614258
# 43.1722412109375
# 47.27424240112305
# 54.10360336303711
# 46.103816986083984
# 44.263038635253906
# 52.168731689453125
# 52.452064514160156
# 52.24720001220703
# 41.1527099609375
# 52.056793212890625
# 52.23674011230469
# 44.31831359863281
# 48.00018310546875
# 44.81946563720703
# 44.68537139892578
# 51.895137786865234
# 44.394039154052734
# 49.353031158447266
# 57.85128402709961
# 41.05795669555664
# 48.69831466674805
# 54.12485885620117
# 51.40514373779297
# 37.68923568725586
# 49.5958366394043
# 46.2859001159668
# 50.23696517944336
# 44.376121520996094
# 43.036373138427734
# 43.01851272583008
# 46.76396942138672
# 34.134307861328125
# 46.29771423339844
# 39.694007873535156

# %%
plt.plot(stepi, lossi)

# %%
C.shape
# Out:
# torch.Size([21732, 2])

# %%
sorted_occurrences[:100]
# Out:
# [(9, 39744),
#  (17993, 34127),
#  (11, 30659),
#  (736, 21745),
#  (18297, 16552),
#  (12375, 14852),
#  (101, 10351),
#  (8322, 9668),
#  (9118, 8837),
#  (21712, 8611),
#  (8592, 7957),
#  (17982, 7697),
#  (19733, 7322),
#  (20108, 5633),
#  (8135, 5351),
#  (9707, 5031),
#  (8416, 4695),
#  (12156, 4598),
#  (8523, 4566),
#  (1226, 4497),
#  (12449, 3958),
#  (1128, 3945),
#  (0, 3925),
#  (2460, 3664),
#  (7097, 3465),
#  (16153, 3361),
#  (8884, 3295),
#  (20392, 3257),
#  (9690, 3232),
#  (100, 3135),
#  (15530, 2834),
#  (566, 2697),
#  (7379, 2664),
#  (1600, 2414),
#  (19886, 2405),
#  (2492, 2373),
#  (18064, 2086),
#  (19987, 2069),
#  (18124, 2010),
#  (12451, 2004),
#  (19939, 2001),
#  (19910, 1982),
#  (8306, 1943),
#  (13838, 1867),
#  (16665, 1789),
#  (13275, 1779),
#  (722, 1613),
#  (19181, 1550),
#  (18005, 1512),
#  (12525, 1503),
#  (1661, 1474),
#  (4871, 1469),
#  (19924, 1453),
#  (18003, 1437),
#  (18041, 1364),
#  (20251, 1350),
#  (11176, 1263),
#  (12469, 1263),
#  (1013, 1224),
#  (12620, 1223),
#  (12199, 1216),
#  (12096, 1174),
#  (8912, 1156),
#  (11805, 1135),
#  (3964, 1110),
#  (11920, 1061),
#  (10954, 1059),
#  (11612, 1050),
#  (20042, 1033),
#  (738, 1026),
#  (8524, 1011),
#  (132, 999),
#  (9579, 999),
#  (5273, 955),
#  (18255, 920),
#  (18025, 899),
#  (6509, 891),
#  (7308, 871),
#  (13841, 869),
#  (19882, 859),
#  (8778, 850),
#  (19782, 844),
#  (16745, 839),
#  (10057, 836),
#  (444, 825),
#  (1673, 819),
#  (6491, 817),
#  (12427, 799),
#  (21096, 775),
#  (19386, 769),
#  (15312, 766),
#  (18138, 763),
#  (11263, 760),
#  (20400, 756),
#  (10493, 730),
#  (15854, 718),
#  (1685, 714),
#  (15333, 712),
#  (452, 701),
#  (7783, 699)]

# %%
display_no = 300

most_common_tokens = [i[0] for i in sorted_occurrences[:display_no]]

# %%
plt.figure(figsize=(8, 8))

plt.scatter(C[most_common_tokens, 0].data, C[most_common_tokens, 1].data, s=display_no)
for i in most_common_tokens:
    plt.text(C[i, 0].item(), C[i, 1].item(), itos[i])
plt.grid("minor")

# %%
for _ in range(10):

    out = []
    context = [11] * block_size  # initialize with all ...
    for i in range(10):
        emb = C[torch.tensor([context])]  # (1,block_size,d)
        h = torch.tanh(emb.view(1, -1) @ W1 + b1)
        logits = h @ W2 + b2
        probs = F.softmax(logits, dim=1)
        ix = torch.multinomial(probs, num_samples=1).item()

        context = context[1:] + [ix]

        out.append(ix)


    print(' '.join(itos[i] for i in out))
# Out:
# in who turn admitting heard said , and you who
# in i in he she with him unwounded in and
# he in in or with and agonized , kaysárov are
# in he in he in , in a in he
# in his , go , to night , of ‘against
# in he a squatted , , but in who that
# rostopchín in him rostopchín who that how and in in
# in he a was a in he that he a
# in he , recite blameless good-looking be responsibilities shoulder ”
# you him in he a was in or by a

# %%
prompt = "it me that"

for _ in range(10):
    
    context_words = prompt.split(" ")
    context = [stoi[i] for i in context_words]
    
    out = []
    for i in range(10):
        emb = C[torch.tensor([context])]  # (1,block_size,d)
        h = torch.tanh(emb.view(1, -1) @ W1 + b1)
        logits = h @ W2 + b2
        probs = F.softmax(logits, dim=1)
        ix = torch.multinomial(probs, num_samples=1).item()

        context = context[1:] + [ix]

        out.append(ix)


    print(' '.join(itos[i] for i in out))
# Out:
# to enticingly , and was in a in he that
# before and in in or by cotillion modesty russo-french obstacle
# , and you it him he you in general—of in
# before and you what , and in who that was
# before and was who that , and , in in
# to enticingly a and it in you or by a
# before and you who that know—well and unwounded awakened and
# his and in who that they and in you him
# before enticingly , , , said his in it in
# , on you in from in in from that a
